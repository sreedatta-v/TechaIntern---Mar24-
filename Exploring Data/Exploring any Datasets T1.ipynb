# %% [markdown]
# Exploring any Dataset using Statistics and Machine Learning.
# Tech-a-Intern
# Task1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("olist_customers_dataset.csv")
data1.head(10)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5  879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7  5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8  5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9  4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# ...

# %%
data2 = pd.read_csv("olist_geolocation_dataset.csv")
data2.head()
# Out:
# <ipython-input-4-3b3890ec481d>:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2 = pd.read_csv("olist_geolocation_dataset.csv")
#    geolocation_zip_code_prefix geolocation_lat  geolocation_lng  \
# 0                         1037      -23.545621       -46.639292
# 1                         1046      -23.546081       -46.644820
# 2                         1046      -23.546129       -46.642951
# 3                         1041      -23.544392       -46.639499
# 4                         1035      -23.541578       -46.641607
# 5                         1012      -23.547762       -46.635361
# 6                         1047      -23.546273       -46.641225
# 7                         1013      -23.546923       -46.634264
# 8                         1029      -23.543769       -46.634278
# 9                         1011       -23.54764       -46.636032
#
#   geolocation_city geolocation_state
# ...

# %% [markdown]
# 1. Knowing the Dimensions of Datasets

# %%
print(data2.shape)
# Out:
# (209405, 5)

# %% [markdown]
# 2. Summary of Datasets using Statistics

# %%
data1.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
data2.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lng
# count                209405.000000    209404.000000
# mean                   4771.132991       -46.653780
# std                    1968.061309         0.126856
# min                    1001.000000       -48.889161
# 25%                    3303.000000       -46.735923
# 50%                    4747.000000       -46.659955
# 75%                    6331.000000       -46.577004
# max                    8599.000000       -45.887705

# %% [markdown]
# 3. Datatypes of Elements in Datasets

# %%
data1.dtypes
# Out:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object

# %%
data2.dtypes
# Out:
# geolocation_zip_code_prefix      int64
# geolocation_lat                 object
# geolocation_lng                float64
# geolocation_city                object
# geolocation_state               object
# dtype: object

# %% [markdown]
# 4. Bar-graphs for Datasets

# %%
data1['customer_state'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
data2['geolocation_city'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# 5. Histogram for Datasets

# %%
data1['customer_state'].hist()
# Out:
# <Axes: >

# %%
data2['geolocation_city'].hist()
# Out:
# <Axes: >

# %% [markdown]
# 6. Scattering in Datasets

# %%
data1.plot.scatter(x='customer_zip_code_prefix', y='customer_city')
# Out:
# <Axes: xlabel='customer_zip_code_prefix', ylabel='customer_city'>
